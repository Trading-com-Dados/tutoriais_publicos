# %% [markdown]
# <a href="https://colab.research.google.com/github/Trading-com-Dados/tutoriais_publicos/blob/main/20211108_Visualiza%C3%A7%C3%A3o_das_maiores_criptos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install investpy
import investpy
# Out:
# ...
#      |████████████████████████████████| 4.4 MB 8.1 MB/s
# ...
#      |████████████████████████████████| 235 kB 60.1 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 20.5 MB/s
# ...
#      |████████████████████████████████| 503 kB 39.3 MB/s
# ...
#   Created wheel for investpy: filename=investpy-1.0.7-py3-none-any.whl size=4495221 sha256=acaad1dc27ff3bf43cbaf3abc0853366cd3ab0ff57e4887ad596bff1a3959fa8
#   Stored in directory: /root/.cache/pip/wheels/50/bb/ee/760eeb6cc7ed8efc1b1b23b13b6b9f17fb1ed530fb04bd16f5
# Successfully built investpy
# ...
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2018.9
#     Uninstalling pytz-2018.9:
#       Successfully uninstalled pytz-2018.9
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
bitcoin = investpy.get_crypto_historical_data(crypto='bitcoin',
                                           from_date='01/01/2020',
                                           to_date='06/11/2021')

bitcoin.head()
# Out:
#               Open    High     Low   Close  Volume Currency
# Date
# 2020-01-01  7196.4  7259.4  7180.0  7199.8  420278      USD
# 2020-01-02  7199.7  7209.6  6901.4  6967.0  632778      USD
# 2020-01-03  6967.1  7402.9  6884.1  7343.1  936288      USD
# 2020-01-04  7345.1  7433.1  7291.4  7376.8  523909      USD
# 2020-01-05  7376.8  7501.0  7345.6  7372.5  628142      USD

# %%
bitcoin.Close.plot()

# %%
ethereum = investpy.get_crypto_historical_data(crypto='ethereum',
                                           from_date='01/01/2020',
                                           to_date='06/11/2021')

ethereum.Close.plot()

# %%
binance = investpy.get_crypto_historical_data(crypto='binance coin',
                                           from_date='01/01/2020',
                                           to_date='06/11/2021')

binance.Close.plot()

# %%
solana = investpy.get_crypto_historical_data(crypto='solana',
                                           from_date='01/01/2020',
                                           to_date='06/11/2021')

solana.head()
# Out:
#              Open   High    Low  Close  Volume Currency
# Date
# 2020-06-04  0.586  0.590  0.561  0.589  558954      USD
# 2020-06-05  0.589  0.698  0.575  0.661  578564      USD
# 2020-06-06  0.661  0.661  0.609  0.625  548267      USD
# 2020-06-07  0.625  0.626  0.591  0.608  426422      USD
# 2020-06-08  0.608  0.682  0.608  0.667  550094      USD

# %%
solana.Close.plot()

# %%
tether = investpy.get_crypto_historical_data(crypto='tether',
                                           from_date='01/01/2020',
                                           to_date='06/11/2021')

tether.Close.plot()

# %%
cardano = investpy.get_crypto_historical_data(crypto='cardano',
                                           from_date='01/01/2020',
                                           to_date='06/11/2021')

cardano.Close.plot()

# %%
xrp = investpy.get_crypto_historical_data(crypto='xrp',
                                           from_date='01/01/2020',
                                           to_date='06/11/2021')

xrp.Close.plot()
